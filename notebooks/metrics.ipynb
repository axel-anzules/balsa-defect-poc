# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.4.95

# %%
from ultralytics.data.converter import convert_ndjson_to_yolo

await convert_ndjson_to_yolo(
    "C:\\Users\\ASUS_TUF_I7\\OneDrive\\Documentos\\Docs CV Balsas Defects Project\\balsa-defect-poc\\dataset\\defects-on-wood-balsa-panels-version-with-preprocess.ndjson",
    "C:\\Users\\ASUS_TUF_I7\\OneDrive\\Documentos\\Docs CV Balsas Defects Project\\balsa-defect-poc\\dataset"   
)

print("Conversion completed successfully.")
# Out:
# Converting defects-on-wood-balsa-panels-version-with-preprocess.ndjson → C:\Users\ASUS_TUF_I7\OneDrive\Documentos\Docs CV Balsas Defects Project\balsa-defect-poc\dataset\defects-on-wood-balsa-panels-version-with-preprocess-b8768037 (1903 images): 6% ╸─────────── 121/1903 14.6it/s 1:34<2:02311WARNING Failed to download https://cdn.ul.run/us/i/f6023e922aafd91cf331f946ffe21977.jpg?Expires=1784909715&KeyName=key-v1&Signature=8nmWncRWykfy-p9u30GAcgcFgms after 3 attempts:
# Converting defects-on-wood-balsa-panels-version-with-preprocess.ndjson → C:\Users\ASUS_TUF_I7\OneDrive\Documentos\Docs CV Balsas Defects Project\balsa-defect-poc\dataset\defects-on-wood-balsa-panels-version-with-preprocess-b8768037 (1903 images): 6% ╸─────────── 123/1903 13.8it/s 1:34<2:09WARNING Failed to download https://cdn.ul.run/us/i/1e4247090988162436bf084c72a614db.jpg?Expires=1784909715&KeyName=key-v1&Signature=8cXDjL4EeUe944a_H3Mz6NKdEb0 after 3 attempts:
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="rN9KKfitlN7d4RU8fx0t")
project = rf.workspace("axel-anzules-3acomposites-com").project("poc-defects-on-wood-balsa-panels")
version = project.version(16)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PoC-defects-on-wood-balsa-panels-16 in yolov11:: 100%|██████████| 4041/4041 [00:01<00:00, 2246.11it/s]
